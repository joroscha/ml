# %%
import pandas as pd
from math import log

# %%
zip_price = pd.read_csv("../Data/Zip_MedianValuePerSqft_AllHomes.csv")
price_increase = pd.read_csv("../Data/Zip_PctOfHomesIncreasingInValues_AllHomes.csv")

# %%
pittsburgh_data = price_increase[(price_increase.RegionName>=15000)&(price_increase.RegionName<15500)]
pittsburgh_data
pittsburgh_data_price = zip_price[(zip_price.RegionName>=15000)&(zip_price.RegionName<15500)]

# %%
log_flag = False

pitt_row = pittsburgh_data.iloc[0]
pitt_row_time = pitt_row[pitt_row.index[7:]]
pitt_row_time.index = pd.to_datetime(pitt_row_time.index)
if log_flag:
    pitt_row_time = [log(x) for x in pitt_row_time]
    plt.plot(pitt_row_time)
else:
    pitt_row_time.plot(c = 'blue')


pitt_row = pittsburgh_data.iloc[1]
pitt_row_time = pitt_row[pitt_row.index[7:]]
pitt_row_time.index = pd.to_datetime(pitt_row_time.index)
if log_flag:
    pitt_row_time = [log(x) for x in pitt_row_time]
    plt.plot(pitt_row_time)
else:
    pitt_row_time.plot(c = 'red')

pitt_row = pittsburgh_data.iloc[2]
pitt_row_time = pitt_row[pitt_row.index[7:]]
pitt_row_time.index = pd.to_datetime(pitt_row_time.index)
if log_flag:
    pitt_row_time = [log(x) for x in pitt_row_time]
    plt.plot(pitt_row_time)
else:
    pitt_row_time.plot(c = 'green')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-38855fbcccc0> in <module>()
#      29     pitt_row_time.plot(c = 'green')
#      30
# ---> 31 plt.show()
#      32
#      33
#
# NameError: name 'plt' is not defined

# %%
pittsburgh_data_byYear = pd.concat([pittsburgh_data_price.ix[:,1], pittsburgh_data_price[pittsburgh_data_price.columns[7:]]], axis = 1)

# %%
pittsburgh_data_byYear.columns
# Out:
# Index([u'RegionName', u'1996-04', u'1996-05', u'1996-06', u'1996-07',
#        u'1996-08', u'1996-09', u'1996-10', u'1996-11', u'1996-12',
#        ...
#        u'2016-05', u'2016-06', u'2016-07', u'2016-08', u'2016-09', u'2016-10',
#        u'2016-11', u'2016-12', u'2017-01', u'2017-02'],
#       dtype='object', length=252)

# %%
pittsburgh_byZip = pittsburgh_data_byYear.groupby('RegionName', axis = 0).median()

# %%
pittsburgh_byZip
# Out:
#             1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  \
# RegionName
# 15001          59.0     60.0     60.0     61.0     61.0     61.0     60.0
# 15003          41.0     41.0     41.0     41.0     41.0     41.0     41.0
# 15005          62.0     63.0     64.0     64.0     65.0     65.0     66.0
# 15009          56.0     57.0     57.0     58.0     58.0     58.0     58.0
# 15010          53.0     54.0     55.0     56.0     56.0     56.0     56.0
# 15012          48.0     47.0     46.0     47.0     47.0     47.0     47.0
# 15014          35.0     35.0     34.0     34.0     33.0     33.0     33.0
# 15015          70.0     70.0     70.0     70.0     70.0     70.0     71.0
# 15017          60.0     61.0     61.0     61.0     61.0     62.0     62.0
# 15019           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 15021          41.0     42.0     42.0     42.0     42.0     41.0     42.0
# ...

# %%
flat_zip = pd.melt(pittsburgh_data_byYear, id_vars="RegionName", var_name="Date", value_name="MedSqft")

# %%
years = [flat_zip.Date.ix[i].split('-')[0] for i in range(len(flat_zip))]

# %%
years
# Out:
# ['1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
# ...

# %%
flat_zip['Years'] = years
flat_zip = flat_zip[['RegionName', 'Years', 'MedSqft']]
med_zip = flat_zip.groupby(['RegionName', 'Years']).median()

# %%
med_zip.reset_index()
# Out:
#       RegionName Years  MedSqft
# 0          15001  1996     61.0
# 1          15001  1997     62.0
# 2          15001  1998     65.0
# 3          15001  1999     67.0
# 4          15001  2000     69.0
# 5          15001  2001     73.0
# 6          15001  2002     75.5
# 7          15001  2003     76.5
# 8          15001  2004     81.0
# 9          15001  2005     84.5
# 10         15001  2006     85.0
# 11         15001  2007     84.0
# 12         15001  2008     87.0
# 13         15001  2009     81.5
# 14         15001  2010     86.0
# 15         15001  2011     86.0
# 16         15001  2012     87.0
# 17         15001  2013     90.5
# 18         15001  2014     93.0
# 19         15001  2015     94.0
# 20         15001  2016    102.5
# 21         15001  2017    103.0
# 22         15003  1996     41.0
# 23         15003  1997     42.0
# 24         15003  1998     43.0
# 25         15003  1999     46.0
# 26         15003  2000     47.0
# 27         15003  2001     50.0
# ...
